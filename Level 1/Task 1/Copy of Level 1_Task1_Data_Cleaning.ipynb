# %% [markdown]
# # Customer Churn — Data Cleaning & Preprocessing
#
# ## Objective
#
# The objective of this project is to clean and preprocess a customer churn dataset to prepare it for further data analysis and machine learning.
#
# ## Technologies Used
#
# * Python
# * Pandas
# * NumPy
# * Matplotlib
# * Seaborn
# * Jupyter Notebook
#
# ## Workflow
#
# 1. Load the dataset
# 2. Inspect the dataset
# 3. Identify missing values and duplicate records
# 4. Handle missing and inconsistent data
# 5. Clean and preprocess the data
# 6. Perform basic exploratory analysis
# 7. Prepare the cleaned dataset for further analysis
#
# ## Conclusion
#
# The customer churn dataset was cleaned and preprocessed by identifying and handling data-quality issues. The resulting dataset is prepared for further analysis and machine learning tasks.

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-cde80ed9-5247-4cf4-88fa-a0879db948e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cde80ed9-5247-4cf4-88fa-a0879db948e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', 'churn-bigml-20.csv', 'sample_data']

# %%
import pandas as pd

df = pd.read_csv('/content/churn-bigml-20.csv')

df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
print("State values:")
print(df["State"].unique())

print("\nInternational plan values:")
print(df["International plan"].unique())

print("\nVoice mail plan values:")
print(df["Voice mail plan"].unique())

print("\nChurn values:")
print(df["Churn"].unique())
# Out:
# State values:
# ['LA' 'IN' 'NY' 'SC' 'HI' 'AK' 'MI' 'ID' 'VA' 'WI' 'MN' 'VT' 'MT' 'MA'
#  'KY' 'CO' 'AZ' 'CA' 'WA' 'NE' 'OH' 'MO' 'AL' 'NH' 'NM' 'OR' 'TX' 'MS'
#  'WY' 'FL' 'KS' 'NC' 'SD' 'OK' 'CT' 'RI' 'DE' 'UT' 'NV' 'DC' 'ME' 'IL'
#  'NJ' 'MD' 'WV' 'PA' 'ND' 'AR' 'TN' 'IA' 'GA']
#
# International plan values:
# ['No' 'Yes']
#
# Voice mail plan values:
# ['No' 'Yes']
#
# Churn values:
# [False  True]

# %%
df.to_csv('/content/churn_cleaned_task1.csv', index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', 'churn-bigml-20.csv', 'churn_cleaned_task1.csv', 'sample_data']

# %%
cleaned_df = pd.read_csv('/content/churn_cleaned_task1.csv')

print("Shape:", cleaned_df.shape)
print("\nFirst 5 rows:")
display(cleaned_df.head())
# Out:
# Shape: (667, 20)
#
# First 5 rows:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
from google.colab import files

files.download('/content/churn_cleaned_task1.csv')
